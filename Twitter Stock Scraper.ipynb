# %%
import sys
# !{sys.executable} -m pip install GetOldTweets3

import GetOldTweets3 as got
import pandas as pd
import os as os
from pathlib import Path
# Out:
# ...
#   Using cached GetOldTweets3-0.0.11-py3-none-any.whl (13 kB)
# ...
#   Using cached pyquery-1.4.1-py2.py3-none-any.whl (22 kB)
# ...
#   Using cached cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# ...

# %%
text_query = ['$ARR', '$BA']
count = 300

p = Path('C:/Users/bryan/OneDrive/Coding Projects/Stock CSV') 

for i in text_query:

    # Creation of query object
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch(i)\
                                            .setMaxTweets(count)

    # Creation of list that contains all tweets
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)

    # Creating list of chosen tweet data
    text_tweets = [[tweet.date, tweet.text] for tweet in tweets]

    df = pd.DataFrame(text_tweets, columns = ['date','text'])

    df.to_csv(Path(p,i+'_tweets'+".csv"), index=False)
    
    df_subset = []

    search_words = ['http','buy','sell']

    for j in search_words:
        a = df[df.text.str.contains('|'.join(search_words))]
        df2 = pd.DataFrame(a)
        print(df2)
       
    df2.to_csv(Path(p, i+'_scrubbed_tweets'+".csv"), index=False)
# Out:
#                          date  \
# 2   2020-04-24 19:28:33+00:00
# 10  2020-04-22 19:52:09+00:00
# 12  2020-04-22 02:18:49+00:00
# 13  2020-04-21 21:30:02+00:00
# 16  2020-04-21 03:13:42+00:00
# ..                        ...
# 295 2020-03-15 12:19:57+00:00
# 296 2020-03-15 12:17:24+00:00
# 297 2020-03-15 12:16:46+00:00
# 298 2020-03-15 10:31:07+00:00
# 299 2020-03-15 10:30:38+00:00
#
#                                                   text
# 2    $ARR are under performed $ladr and $two. Stron...
# 10   $ARR has a poor technical rating and the quali...
# 12   $ARR in Downtrend: 50-day Moving Average moved...
# 13   #Earnings Tomorrow-P3 $T $TDY $TMO $WWW $AKZOY...
# 16   $ARR in Downtrend: 50-day Moving Average moved...
# ..                                                 ...
# 295  James R. Mountain Acquires 3,000 Shares of ARM...
# 296  Insider Buying: ARMOUR Residential REIT, Inc. ...
# 297  James R. Mountain Acquires 3,000 Shares of ARM...
# ...
